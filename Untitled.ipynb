# %%
import h5py
import numpy as np
from matplotlib import pyplot as plt

# %%
h5f = h5py.File('sample.hdf5','r')
print(h5f.keys())
# Out:
# <KeysViewHDF5 ['Center', 'GPS', 'LIDAR', 'Left', 'Right']>

# %%
h5f['Center']
# Out:
# <HDF5 dataset "Center": shape (600, 800, 4), type "|u1">

# %%
center = h5f['Center'][:, :, :]*1.

# %%
center = center[:, :, :]/255.

#Remember to always make sure to switch rgb values !!!!
permute_array = [2, 1, 0]
plt.imshow(center[:, :, permute_array])

# %%
center = h5f['Left'][:, :, :]*1.
#Remember to always make sure to switch rgb values !!!!
permute_array = [2, 1, 0]
plt.imshow(center[:, :, permute_array]/255.)

# %%
center = h5f['Right'][:, :, :]*1.
#Remember to always make sure to switch rgb values !!!!
permute_array = [2, 1, 0]
plt.imshow(center[:, :, permute_array]/255.)
