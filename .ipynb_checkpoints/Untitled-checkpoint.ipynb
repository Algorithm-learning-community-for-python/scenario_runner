# %%
import h5py
import numpy as np
from matplotlib import pyplot as plt

# %%
h5f = h5py.File('sample.hdf5','r')
print(h5f.keys())
# Out:
# <KeysViewHDF5 ['Center', 'GPS', 'LIDAR', 'Left', 'Right']>

# %%
h5f['Center']
# Out:
# <HDF5 dataset "Center": shape (600, 800, 4), type "|u1">

# %%
center = h5f['Center']*1.

# %%
from itertools import permutations
permute_array = [0, 1, 2]
plt.imshow(center[:, :, permute_array])

print(center[:, :, permute_array].shape)
print(center.shape)
# for j in permutations(permute_array):
#     print(j)
#     print(center[:, :, j].shape)
#     plt.imshow(center[:, :, j])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (600, 800, 3)
# (600, 800, 4)

# %%
n

plt.imshow(center[:, :, 2]/255.)

# %%
plt.imshow(h5f['Center'])
